# %%
import folium
import pandas

# %%
file=pandas.read_csv('Volcanoes.txt')

# %%
file
# Out:
#     VOLCANX020    NUMBER                     NAME       LOCATION  \
# 0        509.0  1201-01=                    Baker  US-Washington
# 1        511.0  1201-02-             Glacier Peak  US-Washington
# 2        513.0  1201-03-                  Rainier  US-Washington
# 3        515.0  1201-05-               St. Helens  US-Washington
# 4        516.0  1201-04-                    Adams  US-Washington
# 5        517.0  1201-06-              West Crater  US-Washington
# 6        518.0  1201-07-            Indian Heaven  US-Washington
# 7        519.0  1202-01-                     Hood      US-Oregon
# 8        521.0  1202-02-                Jefferson      US-Oregon
# 9        522.0  1202-03-         Blue Lake Crater      US-Oregon
# 10       523.0  1202-04-      Sand Mountain Field      US-Oregon
# 11       524.0  1202-05-               Washington      US-Oregon
# 12       525.0  1202-06-                  Belknap      US-Oregon
# ...

# %%
file.columns
# Out:
# Index(['VOLCANX020', 'NUMBER', 'NAME', 'LOCATION', 'STATUS', 'ELEV', 'TYPE',
#        'TIMEFRAME', 'LAT', 'LON'],
#       dtype='object')

# %%
lan=list(file['LAT'])
lon=list(file['LON'])
elev=list(file['ELEV'])
print(lan)
print('/n')
print(lon)
# Out:
# [48.7767982, 48.1118011, 46.8698006, 46.1997986, 46.20579910000001, 45.8797989, 45.929798100000006, 45.3737984, 44.691799200000005, 44.4197998, 44.3797989, 44.331798600000006, 44.2848015, 44.1697998, 44.099800099999996, 43.978801700000005, 43.7218018, 43.569801299999995, 43.5119019, 43.240798999999996, 43.471900899999994, 43.3609009, 42.9299011, 44.4299011, 43.0998993, 43.1498985, 42.9999008, 43.419899, 43.4999008, 43.1799011, 42.605899799999996, 41.579898799999995, 42.8799019, 41.419899, 41.1778984, 40.954898799999995, 40.77989960000001, 40.6799011, 40.6299019, 40.491901399999996, 38.9698982, 39.3749008, 39.6500015, 37.9999008, 38.970001200000006, 37.8799019, 37.6918983, 37.6999016, 37.579898799999995, 37.0199013, 37.5800018, 37.257, 37.32799910000001, 36.3578987, 36.02989960000001, 36.3800011, 34.75, 35.8699989, 35.3699989, 34.5499992, 34.7999992, 33.7801018]
# /n
# ...

# %%
def color_producer(elevation):
    if elevation<=1000:
        return 'blue'
    elif 1000 < elevation<=3000: 
        return 'orange'
    else:
        return 'red'

# %%
# map=folium.Map(location=[28.3,77.3] ,zoom_start=8,tiles='Mapbox Bright')

# %%
fg=folium.FeatureGroup(name='My map')

# %%
#fg.add_child(folium.Marker(location=[28.3521,77.3354] ,popup='i am here',icon=folium.Icon(color='green')))

# %%
for la , lo , el in zip(lan,lon,elev):
    fg.add_child(folium.Marker(location=[la , lo] ,popup= folium.Popup(str(el),parse_html=True) ,icon=folium.Icon(color= color_producer(el))))

# %%
map.add_child(fg)
map.add_child(folium.LayerControl())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-e9ac01f4fdb5> in <module>()
# ----> 1 map.add_child(fg)
#       2 map.add_child(folium.LayerControl())
#
# AttributeError: type object 'map' has no attribute 'add_child'

# %%
map.save('map1.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-07df898df363> in <module>()
# ----> 1 map.save('map1.html')
#
# AttributeError: type object 'map' has no attribute 'save'
